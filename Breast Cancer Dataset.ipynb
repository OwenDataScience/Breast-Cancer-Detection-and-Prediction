# %%
import pandas as pd
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

# Number of rows in the dataset
num_rows = 1000

# Generate synthetic data for the dataset
data = {
    'Patient_ID': range(1, num_rows + 1),
    'Age': np.random.randint(25, 80, size=num_rows),
    'Gender': np.random.choice(['Male', 'Female'], size=num_rows),
    'Family_History': np.random.choice(['Yes', 'No'], size=num_rows),
    'Previous_Biopsy': np.random.choice(['Yes', 'No'], size=num_rows),
    'BRCA1_Mutation': np.random.choice(['Yes', 'No'], size=num_rows),
    'BRCA2_Mutation': np.random.choice(['Yes', 'No'], size=num_rows),
    'Biomarker_Level': np.random.choice(['Low', 'Medium', 'High'], size=num_rows),
    'Mammogram_Features': [np.random.rand(10) for _ in range(num_rows)],
    'Diagnosis': np.random.choice(['Malignant', 'Benign'], size=num_rows),
    'Stage': np.random.choice(['I', 'II', 'III', 'IV'], size=num_rows),
    'Subtype': np.random.choice(['Luminal A', 'Luminal B', 'HER2-enriched', 'Triple-negative'], size=num_rows)
}

# Create DataFrame
df = pd.DataFrame(data)

# Display first few rows of the DataFrame
df
# Out:
#      Patient_ID  Age  Gender Family_History Previous_Biopsy BRCA1_Mutation  \
# 0             1   63  Female            Yes              No            Yes
# 1             2   76    Male             No              No             No
# 2             3   53  Female            Yes              No            Yes
# 3             4   39    Male             No             Yes            Yes
# 4             5   67    Male             No             Yes            Yes
# ..          ...  ...     ...            ...             ...            ...
# 995         996   56    Male             No              No            Yes
# 996         997   27  Female             No              No            Yes
# 997         998   51    Male             No             Yes             No
# 998         999   53  Female            Yes              No             No
# 999        1000   56    Male            Yes             Yes             No
#
#     BRCA2_Mutation Biomarker_Level  \
# ...

# %%
import pandas as pd
import numpy as np

# URL of the dataset
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data"

# Define column names based on dataset description
column_names = [
    "ID",
    "Diagnosis",
    "Mean Radius",
    "Mean Texture",
    "Mean Perimeter",
    "Mean Area",
    "Mean Smoothness",
    "Mean Compactness",
    "Mean Concavity",
    "Mean Concave Points",
    "Mean Symmetry",
    "Mean Fractal Dimension",
    "SE Radius",
    "SE Texture",
    "SE Perimeter",
    "SE Area",
    "SE Smoothness",
    "SE Compactness",
    "SE Concavity",
    "SE Concave Points",
    "SE Symmetry",
    "SE Fractal Dimension",
    "Worst Radius",
    "Worst Texture",
    "Worst Perimeter",
    "Worst Area",
    "Worst Smoothness",
    "Worst Compactness",
    "Worst Concavity",
    "Worst Concave Points",
    "Worst Symmetry",
    "Worst Fractal Dimension"
]

# Load dataset into a Pandas DataFrame
breast_cancer_df = pd.read_csv(url, header=None, names=column_names)


# Display the DataFrame
breast_cancer_df
# Out:
#            ID Diagnosis  Mean Radius  Mean Texture  Mean Perimeter  Mean Area  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
breast_cancer_df['Diagnosis'].value_counts()
# Out:
# Diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

# URL of the dataset
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data"

# Define column names based on dataset description
column_names = [
    "ID",
    "Diagnosis",
    "Mean Radius",
    "Mean Texture",
    "Mean Perimeter",
    "Mean Area",
    "Mean Smoothness",
    "Mean Compactness",
    "Mean Concavity",
    "Mean Concave Points",
    "Mean Symmetry",
    "Mean Fractal Dimension",
    "SE Radius",
    "SE Texture",
    "SE Perimeter",
    "SE Area",
    "SE Smoothness",
    "SE Compactness",
    "SE Concavity",
    "SE Concave Points",
    "SE Symmetry",
    "SE Fractal Dimension",
    "Worst Radius",
    "Worst Texture",
    "Worst Perimeter",
    "Worst Area",
    "Worst Smoothness",
    "Worst Compactness",
    "Worst Concavity",
    "Worst Concave Points",
    "Worst Symmetry",
    "Worst Fractal Dimension"
]

# Load dataset into a Pandas DataFrame
breast_cancer_df = pd.read_csv(url, header=None, names=column_names)

def generate_age(diagnosis_series, total_count):
    age_range = []
    counts = [0.1, 0.15, 0.25, 0.5]  # Percentages for age ranges
    age_ranges = [(20, 41), (41, 51), (51, 61), (61, 81)]
    for diagnosis in diagnosis_series:
        if diagnosis == 'B':
            age_range.append(np.random.randint(20, 81))
        elif diagnosis == 'M':
            for i, count in enumerate(counts):
                age_range.extend(np.random.randint(age_ranges[i][0], age_ranges[i][1], int(count * total_count)))
    np.random.shuffle(age_range)
    return age_range[:total_count]

def generate_additional_columns(num_rows):
    family_history = np.random.choice(['Yes', 'No'], size=num_rows)
    stage = np.random.choice(['I', 'II', 'III', 'IV'], size=num_rows)
    return family_history, stage

# Add age column
breast_cancer_df['Age'] = generate_age(breast_cancer_df['Diagnosis'], len(breast_cancer_df))

# Add 'Family_History' and 'Stage' columns
num_rows = len(breast_cancer_df)
breast_cancer_df['Family_History'], breast_cancer_df['Stage'] = generate_additional_columns(num_rows)

# SAVE TO A csv FILE

file_path = r"C:\Users\Sire Ode\OneDrive\Attachments\Desktop\Python Developer\breast_cancer_data.csv"
breast_cancer_df.to_csv(file_path, index=False)


# Display the DataFrame
breast_cancer_df
# Out:
#            ID Diagnosis  Mean Radius  Mean Texture  Mean Perimeter  Mean Area  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
# 10% of the total count of where Diagnosis = M 
breast_cancer_df[(breast_cancer_df['Age'] >= 20) & (breast_cancer_df['Age'] <= 41) & (breast_cancer_df['Diagnosis'] == 'M')]

# 15% of the total count of where Diagnosis = M 
breast_cancer_df[(breast_cancer_df['Age'] >= 41) & (breast_cancer_df['Age'] <= 51) & (breast_cancer_df['Diagnosis'] == 'M')]

# 25% of the total count of where Diagnosis = M 
breast_cancer_df[(breast_cancer_df['Age'] >= 51) & (breast_cancer_df['Age'] <= 61) & (breast_cancer_df['Diagnosis'] == 'M')]

# 50% of the total count of where Diagnosis = M 
breast_cancer_df[(breast_cancer_df['Age'] >= 61) & (breast_cancer_df['Age'] <= 81) & (breast_cancer_df['Diagnosis'] == 'M')]
# Out:
#            ID Diagnosis  Mean Radius  Mean Texture  Mean Perimeter  Mean Area  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 6      844359         M        18.25         19.98          119.60     1040.0
# 7    84458202         M        13.71         20.83           90.20      577.9
# 9    84501001         M        12.46         24.04           83.97      475.9
# ..        ...       ...          ...           ...             ...        ...
# 533  91930402         M        20.47         20.67          134.70     1299.0
# 535    919555         M        20.55         20.86          137.80     1308.0
# 536  91979701         M        14.27         22.55           93.77      629.8
# 562    925622         M        15.22         30.62          103.40      716.9
# 567    927241         M        20.60         29.33          140.10     1265.0
#
# ...

# %%
breast_cancer_df[breast_cancer_df['Diagnosis'] == 'M']
# Out:
#            ID Diagnosis  Mean Radius  Mean Texture  Mean Perimeter  Mean Area  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 563    926125         M        20.92         25.09          143.00     1347.0
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
#
# ...

# %%
import pandas as pd

# URL of the raw file on GitHub
url = "https://raw.githubusercontent.com/OwenDataScience/Breast-Cancer-Detection-and-Prediction/main/breast_cancer_data.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(url)

# Now you can work with the DataFrame 'df'
df
# Out:
#            ID Diagnosis  Mean Radius  Mean Texture  Mean Perimeter  Mean Area  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...
